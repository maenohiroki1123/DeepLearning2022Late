# %% [markdown]
# <a href="https://colab.research.google.com/github/maenohiroki1123/DeepLearning2022Late/blob/main/Matplotlib0927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # matplotlibグラフ表示のライブラリ

# %% [markdown]
# ### ライブラリの読み込み

# %%
# 読み込み命令
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### グラフ出力するデータの準備

# %%
t=np.arange(0.0,2.0,0.01)# 0.0から2.0まで0.01刻みでデータを生成
# SINカーブを描くために、元データのsin値を取得して変数sに設定
s=1+np.sin(2*np.pi*t)
fig,ax=plt.subplots()
ax.plot(t,s)
# グラフaxにラベルを設定する
ax.set(xlabel='time(s)',ylabel='voltage(mV)',title='About as simple as it gets, folks')
# グラフaxにグリッドをつける
ax.grid()
# pyplotで表示
ax.plot(t,s)
plt.show()

# %% [markdown]
# ## グラフのラベルとグリッドを描画させる

# %%
# グラフaxにラベルを設定する
ax.set(xlabel='time(s)',ylabel='voltage(mV)',title='About as simple as it gets, folks')
# グラフaxにグリッドをつける
ax.grid()

# %% [markdown]
# ### 出来上がったグラフをpyplotで表示する

# %%
# pyplotで表示
ax.plot(t,s)
plt.show()
